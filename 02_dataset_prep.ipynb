# %%
import pandas as pd

# %%
df = pd.read_csv("data/yoga_ds_with_keypoints.csv")
df.head()
# Out:
#            pose  filename format  width  height    nose_x    nose_y  \
# 0  hanumanasana   3-0.png    PNG    440     299  0.261698  0.512255
# 1  hanumanasana  21-0.png    PNG    466     453  0.394864  0.491497
# 2  hanumanasana  45-0.png    PNG    397     228  0.430713  0.753430
# 3  hanumanasana  67-0.png    PNG    493     402  0.369197  0.440116
# 4  hanumanasana  25-0.png    PNG    518     336  0.262922  0.548760
#
#    nose_score  left_eye_x  left_eye_y  ...  left_knee_score  right_knee_x  \
# 0    0.630277    0.237344    0.517355  ...         0.720410      0.722782
# 1    0.831882    0.370693    0.487102  ...         0.849817      0.805349
# 2    0.800470    0.439265    0.780632  ...         0.298566      0.719260
# 3    0.678368    0.368485    0.460600  ...         0.868513      0.786196
# 4    0.764848    0.245587    0.531681  ...         0.888956      0.755988
#
#    right_knee_y  right_knee_score  left_ankle_x  left_ankle_y  \
# ...

# %%
# yx coordinates are normalized to image frame, i.e. range in [0.0, 1.0] of the 17 keypoints
df.describe()
# Out:
#              width       height       nose_x       nose_y   nose_score  \
# count  5994.000000  5994.000000  5994.000000  5994.000000  5994.000000
# mean    429.707708   361.710878     0.402485     0.505240     0.643202
# std     237.293535   204.589043     0.208851     0.265225     0.168151
# min      16.000000    26.000000     0.002803    -0.020719     0.001595
# 25%     269.000000   233.250000     0.230323     0.301329     0.548488
# 50%     393.000000   324.000000     0.385639     0.503402     0.670592
# 75%     553.000000   446.000000     0.550888     0.714601     0.772368
# max    3949.000000  4262.000000     0.990988     1.010201     0.926177
#
#         left_eye_x   left_eye_y  left_eye_score  right_eye_x  right_eye_y  \
# count  5994.000000  5994.000000     5994.000000  5994.000000  5994.000000
# mean      0.392777     0.512010        0.674613     0.392655     0.498716
# std       0.217474     0.270520        0.164364     0.217472     0.270923
# ...

# %%
df_Xy = df.loc[:, df.columns.str.endswith(("_x", "_y", "pose"))]
df_Xy.head()
# Out:
#            pose    nose_x    nose_y  left_eye_x  left_eye_y  right_eye_x  \
# 0  hanumanasana  0.261698  0.512255    0.237344    0.517355     0.238441
# 1  hanumanasana  0.394864  0.491497    0.370693    0.487102     0.375714
# 2  hanumanasana  0.430713  0.753430    0.439265    0.780632     0.419011
# 3  hanumanasana  0.369197  0.440116    0.368485    0.460600     0.366005
# 4  hanumanasana  0.262922  0.548760    0.245587    0.531681     0.244322
#
#    right_eye_y  left_ear_x  left_ear_y  right_ear_x  ...  right_hip_x  \
# 0     0.486026    0.242483    0.497878     0.248089  ...     0.651845
# 1     0.461120    0.381811    0.450995     0.400140  ...     0.807697
# 2     0.763575    0.482887    0.787360     0.431683  ...     0.622483
# 3     0.458955    0.407975    0.471238     0.402241  ...     0.778978
# 4     0.532350    0.257699    0.483209     0.258080  ...     0.624212
#
#    right_hip_y  left_knee_x  left_knee_y  right_knee_x  right_knee_y  \
# ...

# %%
df_Xy.to_csv("data/yoga_ds_Xy.csv", index=False)
